# %%
library(tidyquant) 
library(forecast)

# %%
getSymbols("MRNA", from = '2020-03-08', to = "2021-03-08",warnings = FALSE, auto.assign = TRUE)
# Out:
# ‘getSymbols’ currently uses auto.assign=TRUE by default, but will
# use auto.assign=FALSE in 0.5-0. You will still be able to use
# ‘loadSymbols’ to automatically load data. getOption("getSymbols.env")
# and getOption("getSymbols.auto.assign") will still be checked for
# alternate defaults.
#
# This message is shown once per session and may be disabled by setting
# options("getSymbols.warning4.0"=FALSE). See ?getSymbols for details.
# [1] "MRNA"

# %%
# Time series graph with forecst 
plot(MRNA$MRNA.Close)
# Out:
# plot without title

# %%
model=auto.arima(MRNA$MRNA.Close)

# %%
forecast(model,10) 
plot(forecast(model,10))
# Out:
#     Point Forecast    Lo 80    Hi 80     Lo 95    Hi 95
# 252         132.19 125.4638 138.9162 121.90313 142.4769
# 253         132.19 122.6777 141.7023 117.64217 146.7378
# 254         132.19 120.5398 143.8402 114.37262 150.0074
# 255         132.19 118.7376 145.6424 111.61627 152.7637
# 256         132.19 117.1497 147.2303 109.18787 155.1921
# 257         132.19 115.7142 148.6658 106.99242 157.3876
# 258         132.19 114.3941 149.9859 104.97351 159.4065
# 259         132.19 113.1654 151.2146 103.09435 161.2857
# 260         132.19 112.0113 152.3687 101.32940 163.0506
# 261         132.19 110.9198 153.4602  99.66007 164.7199
# Plot with title “Forecasts from ARIMA(0,1,0)”

# %%
# Candlestick graphs 
chart_Series(MRNA,name="Moderna") 
chart_Series(MRNA,name="Moderna",subset="2021-01/2021-03")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ARIMA to forecast stock prices

# %% [markdown]
# Forecast for windows and get delta between backtest and forecasted

# %% [markdown]
# CIs increase as go into future, values predicted same
#
# A lot of uncertainty about the future values

# %% [markdown]
# Quiz will be very similar to this.
# any observation is a good one at this stage.

# %% [markdown]
# depends on the stock time period etc
